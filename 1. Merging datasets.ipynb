# %%
# Enabling reloading extension to use external python files
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import os.path
import os
import columns
import datasets
import seasons
import directory_utils

# %%
data_dict = {sheet_name: [] for sheet_name in datasets.SHEETS_NAMES}
data_dict
# Out:
# {'111': [], '222': [], '333': [], '265': []}

# %%
def read_sheet_as_data_frame(xls, sheet_name):
    sheet = pd.read_excel(xls, sheet_name=sheet_name)
    
    columns_to_drop = []
    for column in sheet.columns:
        if(columns.UNNAMED in column):
            columns_to_drop.append(column)
    df = sheet.drop(columns_to_drop, axis=1) 
    
    return df

# %%
spreadsheet_names = [str(1997+w) for w in range(0,20)]

for name in spreadsheet_names:
    file_path = datasets.ORIGINAL_DATA_SETS_PATH + "/" + name + ".xlsx"
    
    if os.path.isfile(file_path):
        with pd.ExcelFile(file_path) as xls:          
            for sheet_name in datasets.SHEETS_NAMES:
                if sheet_name in xls.sheet_names:
                    df = read_sheet_as_data_frame(xls,sheet_name)
                    data_dict[sheet_name].append(df)

    else:
        print('File "' + file_path + '" was not found.')

# %%
data_frames = {sheet_name: pd.concat(data_frames) for sheet_name, data_frames in data_dict.items()}
for name, data_frame in data_frames.items():
    print('Shape of \"' + name + '\":' + str(data_frame.shape))
# Out:
# Shape of "111":(1050445, 18)
# Shape of "222":(6914, 21)
# Shape of "333":(26001, 10)
# Shape of "265":(6864, 13)

# %%
directory_utils.create_if_doesnt_exist(datasets.MERGED_CSVS_DIRECTORY_PATH)

for sheet_name, data_frame in data_frames.items():
    csv_output_file_path = datasets.MERGED_CSVS_DIRECTORY_PATH + '/' + sheet_name + '.csv'
    data_frame.to_csv(csv_output_file_path , index = False, encoding=datasets.DEFAULT_CSV_ENCODING)

# %%
data_frame_111 = data_frames[datasets.SHEET_111_NAME]
data_frame_222 = data_frames[datasets.SHEET_222_NAME]
data_frame_333 = data_frames[datasets.SHEET_333_NAME]
data_frame_265 = data_frames[datasets.SHEET_265_NAME]

# %% [markdown]
# ### Analyzing 111 data frame

# %%
data_frame_111.head(2)
# Out:
#    Cod   Ano  Dia Juliano  Hora - minuto  \
# 0  111  1997          1.0             10
# 1  111  1997          1.0             20
#
#    Veloc. Instantânea do Vento a 5 metros (m/s)  \
# 0                                       1618.00
# 1                                          0.99
#
#    Veloc. Instantânea do Vento a 2 metros (m/s)  \
# 0                                      1115.000
# 1                                         0.763
#
#    Direção do Vento no instante da aquisição (°)  \
# 0                                           8.32
# 1                                          20.59
#
#    Radiação Incidente total de 10 leituras (KW/m2)  \
# 0                                              0.0
# 1                                              0.0
#
#    Radiação Refletida Total de 10 leituras (KW/m2)  \
# 0                                              0.0
# 1                                              0.0
#
#    Fluxo Positivo de calor no solo total de 10 leituras (W/m2)  \
# 0                                                0.0
# 1                                                0.0
#
#    Fluxo negativo de calor no solo . total de 10 leituras (W/m2)  \
# 0                                             -443.0
# 1                                             -443.0
#
#    Umidade relativa Média (%)  Temperatura do Ar Média (°C)  \
# 0                        92.3                         19.84
# 1                        93.1                         19.63
#
#    Temperatura do solo  1 Média (°C) à 3cm no solo  \
# 0                                            21.04
# 1                                            20.97
#
#    Temperatura do solo 2Média (°C) à 6cm no solo   \
# 0                                           22.68
# 1                                           22.65
#
#   Temperatura do solo 3Média (°C) Colocado sensor de UV em 31/07/09  \
# 0                                              24.59
# 1                                              24.52
#
#    Pressão (hPa) Chuva total do período (mm)
# 0          943.0                           0
# 1          943.0                           0

# %%
data_frame_111.columns
# Out:
# Index(['Cod', 'Ano', 'Dia Juliano', 'Hora - minuto',
#        'Veloc. Instantânea do Vento a 5 metros (m/s)',
#        'Veloc. Instantânea do Vento a 2 metros (m/s)',
#        'Direção do Vento no instante da aquisição (°)',
#        'Radiação Incidente total de 10 leituras (KW/m2)',
#        'Radiação Refletida Total de 10 leituras (KW/m2)',
#        'Fluxo Positivo de calor no solo total de 10 leituras (W/m2)',
#        'Fluxo negativo de calor no solo . total de 10 leituras (W/m2)',
#        'Umidade relativa Média (%)', 'Temperatura do Ar Média (°C)',
#        'Temperatura do solo  1 Média (°C) à 3cm no solo',
#        'Temperatura do solo 2Média (°C) à 6cm no solo ',
#        'Temperatura do solo 3Média (°C) Colocado sensor de UV em 31/07/09',
#        'Pressão (hPa)', 'Chuva total do período (mm)'],
#       dtype='object')

# %%
data_frame_111.Cod.unique()
# Out:
# array([111, 333, 265, 222])

# %%
print(data_frame_111[data_frame_111.Cod != 111][columns.YEAR].unique())
# Out:
# [2005]

# %%
data_frame_111.isnull().sum()
# Out:
# Cod                                                                     0
# Ano                                                                     0
# Dia Juliano                                                             0
# Hora - minuto                                                           0
# Veloc. Instantânea do Vento a 5 metros (m/s)                            0
# Veloc. Instantânea do Vento a 2 metros (m/s)                            0
# Direção do Vento no instante da aquisição (°)                           0
# Radiação Incidente total de 10 leituras (KW/m2)                         0
# Radiação Refletida Total de 10 leituras (KW/m2)                         0
# Fluxo Positivo de calor no solo total de 10 leituras (W/m2)             0
# Fluxo negativo de calor no solo . total de 10 leituras (W/m2)        1825
# Umidade relativa Média (%)                                           1826
# Temperatura do Ar Média (°C)                                         1826
# Temperatura do solo  1 Média (°C) à 3cm no solo                      2191
# Temperatura do solo 2Média (°C) à 6cm no solo                        2191
# Temperatura do solo 3Média (°C) Colocado sensor de UV em 31/07/09    2191
# Pressão (hPa)                                                        2191
# Chuva total do período (mm)                                          2191
# dtype: int64

# %%
data_frame_111.describe()
# Out:
#                 Cod           Ano   Dia Juliano  Hora - minuto  \
# count  1.050445e+06  1.050445e+06  1.050445e+06   1.050445e+06
# mean   1.114778e+02  2.006549e+03  1.835618e+02   1.192104e+03
# std    9.895335e+00  5.762457e+00  1.053855e+02   6.927634e+02
# min    1.110000e+02  1.997000e+03 -5.336000e+01   1.000000e+01
# 25%    1.110000e+02  2.002000e+03  9.300000e+01   6.100000e+02
# 50%    1.110000e+02  2.007000e+03  1.840000e+02   1.210000e+03
# 75%    1.110000e+02  2.012000e+03  2.750000e+02   1.810000e+03
# max    3.330000e+02  2.139000e+03  6.540000e+02   6.640000e+03
#
#        Veloc. Instantânea do Vento a 5 metros (m/s)  \
# count                                  1.050445e+06
# mean                                   1.472154e+03
# std                                    1.353874e+03
# min                                   -6.999000e+03
# 25%                                    1.010000e+00
# 50%                                    1.481000e+03
# 75%                                    2.265000e+03
# max                                    6.996000e+03
#
#        Veloc. Instantânea do Vento a 2 metros (m/s)  \
# count                                  1.050445e+06
# mean                                   9.129840e+02
# std                                    1.134761e+03
# min                                    0.000000e+00
# 25%                                    5.390000e-01
# 50%                                    1.010000e+00
# 75%                                    1.716000e+03
# max                                    6.999000e+03
#
#        Direção do Vento no instante da aquisição (°)  \
# count                                   1.050445e+06
# mean                                    2.723121e+02
# std                                     6.693158e+02
# min                                     0.000000e+00
# 25%                                     9.380000e+01
# 50%                                     1.555000e+02
# 75%                                     2.576000e+02
# max                                     6.999000e+03
#
#        Radiação Incidente total de 10 leituras (KW/m2)  \
# count                                     1.050445e+06
# mean                                      7.622076e+02
# std                                       1.611430e+03
# min                                      -6.999000e+03
# 25%                                       0.000000e+00
# 50%                                       0.000000e+00
# 75%                                       4.338000e+02
# max                                       6.999000e+03
#
#        Radiação Refletida Total de 10 leituras (KW/m2)  \
# count                                     1.050445e+06
# mean                                      2.706437e+02
# std                                       8.889303e+02
# min                                       0.000000e+00
# 25%                                       0.000000e+00
# 50%                                       0.000000e+00
# 75%                                       9.890000e-01
# max                                       6.999000e+03
#
#        Fluxo Positivo de calor no solo total de 10 leituras (W/m2)  \
# count                                       1.050445e+06
# mean                                        3.653693e+02
# std                                         1.147225e+03
# min                                         0.000000e+00
# 25%                                         0.000000e+00
# 50%                                         0.000000e+00
# 75%                                         1.788000e+02
# max                                         6.999000e+03
#
#        Fluxo negativo de calor no solo . total de 10 leituras (W/m2)  \
# count                                       1.048620e+06
# mean                                       -1.662485e+03
# std                                         2.796438e+03
# min                                        -6.999000e+03
# 25%                                        -5.298000e+02
# 50%                                        -2.460000e+02
# 75%                                         0.000000e+00
# max                                         6.538000e+03
#
#        Umidade relativa Média (%)  Temperatura do Ar Média (°C)  \
# count                1.048619e+06                  1.048619e+06
# mean                 7.404259e+01                  2.634531e+01
# std                  2.748618e+01                  2.413575e+02
# min                 -6.999000e+03                 -6.999000e+03
# 25%                  6.053000e+01                  1.813000e+01
# 50%                  7.750000e+01                  2.114000e+01
# 75%                  8.920000e+01                  2.510000e+01
# max                  6.836000e+03                  1.822660e+05
#
#        Temperatura do solo  1 Média (°C) à 3cm no solo  \
# count                                     1.048254e+06
# mean                                      1.332214e+03
# std                                       2.725003e+03
# min                                      -6.999000e+03
# 25%                                       2.049000e+01
# 50%                                       2.448000e+01
# 75%                                       3.198000e+01
# max                                       6.999000e+03
#
#        Temperatura do solo 2Média (°C) à 6cm no solo   Pressão (hPa)
# count                                    1.048254e+06   1.048254e+06
# mean                                     1.296305e+03   9.462274e+02
# std                                      2.694402e+03   8.089817e+01
# min                                     -6.999000e+03  -6.999000e+03
# 25%                                      2.117000e+01   9.430000e+02
# 50%                                      2.493000e+01   9.470000e+02
# 75%                                      2.988000e+01   9.520000e+02
# max                                      6.999000e+03   2.802000e+03

# %% [markdown]
# ### Analyzing 222 data frame

# %%
data_frame_222.head(2)
# Out:
#    Cod   Ano Dia Juliano Hora - minuto  \
# 0  222  1997           1          2400
# 1  222  1997           2          2400
#
#    Veloc. máxima do Vento a 5 metros (m/s)  \
# 0                                   6031.0
# 1                                   4756.0
#
#    Veloc. máxima do Vento a 2 metros (m/s)  \
# 0                                   2677.0
# 1                                   1758.0
#
#    Direção do Vento no instante da veloc. Máx.(°)  \
# 0                                            99.6
# 1                                           119.5
#
#   Horário de ocorrência vr máx. veloc. do vento  \
# 0                                          1923
# 1                                            45
#
#    Radiação Incidente Total do dia (KW/m2)  \
# 0                                    270.8
# 1                                    165.3
#
#    Radiação Refletida Total do dia (KW/m2)  ...  \
# 0                                    53.81  ...
# 1                                    27.46  ...
#
#    Fluxo Negativo de calor no solo. Total do dia (KW/m2)  \
# 0                                             -34.76
# 1                                             -26.86
#
#   Temperatura do Ar  Máxima do dia (°C)  \
# 0                                 30.16
# 1                                 26.15
#
#   Horário de ocorrência da Temp. Ar Máxima(°C)  \
# 0                                         1255
# 1                                         1417
#
#   Temperatura do Ar Mínima do dia (°C)  \
# 0                                18.50
# 1                                19.15
#
#    Horário de ocorrência da Temp. Ar Minima  \
# 0                                     551.0
# 1                                    2355.0
#
#    Temperatura do Solo 1 Máxima do dia (°C)  \
# 0                                     34.53
# 1                                     27.66
#
#   Horário de ocorrência da Temp. Solo 1 Máxima.  \
# 0                                          1258
# 1                                          1425
#
#   Temperatura do Solo 1 Mínima do dia (°C)  \
# 0                                    19.15
# 1                                    19.65
#
#    Horário de ocorrência da Temp. Solo 1 minima  Chuva total do dia (mm)
# 0                                         606.0                      0.0
# 1                                        2352.0                      0.0
#
# [2 rows x 21 columns]

# %%
data_frame_222.columns
# Out:
# Index(['Cod', 'Ano', 'Dia Juliano', 'Hora - minuto',
#        'Veloc. máxima do Vento a 5 metros (m/s)',
#        'Veloc. máxima do Vento a 2 metros (m/s)',
#        'Direção do Vento no instante da veloc. Máx.(°)',
#        'Horário de ocorrência vr máx. veloc. do vento',
#        'Radiação Incidente Total do dia (KW/m2)',
#        'Radiação Refletida Total do dia (KW/m2)',
#        'Fluxo positivo de calor no solo Total do dia (KW/m2)',
#        'Fluxo Negativo de calor no solo. Total do dia (KW/m2)',
#        'Temperatura do Ar  Máxima do dia (°C)',
#        'Horário de ocorrência da Temp. Ar Máxima(°C)',
#        'Temperatura do Ar Mínima do dia (°C)',
#        'Horário de ocorrência da Temp. Ar Minima',
#        'Temperatura do Solo 1 Máxima do dia (°C)',
#        'Horário de ocorrência da Temp. Solo 1 Máxima.',
#        'Temperatura do Solo 1 Mínima do dia (°C)',
#        'Horário de ocorrência da Temp. Solo 1 minima',
#        'Chuva total do dia (mm)'],
#       dtype='object')

# %%
data_frame_222.Cod.unique()
# Out:
# array([222], dtype=object)

# %%
print(data_frame_222[data_frame_222.Cod != 222][columns.YEAR].unique())
# Out:
# []

# %%
data_frame_222.isnull().sum()
# Out:
# Cod                                                        0
# Ano                                                        0
# Dia Juliano                                                0
# Hora - minuto                                              0
# Veloc. máxima do Vento a 5 metros (m/s)                    0
# Veloc. máxima do Vento a 2 metros (m/s)                    0
# Direção do Vento no instante da veloc. Máx.(°)             0
# Horário de ocorrência vr máx. veloc. do vento              0
# Radiação Incidente Total do dia (KW/m2)                    0
# Radiação Refletida Total do dia (KW/m2)                    0
# Fluxo positivo de calor no solo Total do dia (KW/m2)       0
# Fluxo Negativo de calor no solo. Total do dia (KW/m2)      0
# Temperatura do Ar  Máxima do dia (°C)                      1
# Horário de ocorrência da Temp. Ar Máxima(°C)               1
# Temperatura do Ar Mínima do dia (°C)                       1
# Horário de ocorrência da Temp. Ar Minima                   1
# Temperatura do Solo 1 Máxima do dia (°C)                   1
# Horário de ocorrência da Temp. Solo 1 Máxima.              1
# Temperatura do Solo 1 Mínima do dia (°C)                   1
# Horário de ocorrência da Temp. Solo 1 minima               2
# Chuva total do dia (mm)                                  151
# dtype: int64

# %%
data_frame_222.describe()
# Out:
#        Veloc. máxima do Vento a 5 metros (m/s)  \
# count                              6914.000000
# mean                               3666.239481
# std                                2038.105213
# min                                   0.000000
# 25%                                3109.000000
# 50%                                4109.000000
# 75%                                5011.000000
# max                                6973.000000
#
#        Veloc. máxima do Vento a 2 metros (m/s)  \
# count                              6914.000000
# mean                               2584.439435
# std                                1860.333669
# min                                   0.000000
# 25%                                   5.090000
# 50%                                2854.000000
# 75%                                3910.250000
# max                                6973.000000
#
#        Direção do Vento no instante da veloc. Máx.(°)  \
# count                                     6914.000000
# mean                                       288.337367
# std                                        625.759617
# min                                          0.000000
# 25%                                        131.900000
# 50%                                        181.100000
# 75%                                        282.600000
# max                                       6897.000000
#
#        Radiação Incidente Total do dia (KW/m2)  \
# count                              6914.000000
# mean                                210.470264
# std                                 275.510678
# min                                   0.000000
# 25%                                 110.600000
# 50%                                 207.700000
# 75%                                 274.100000
# max                                6589.000000
#
#        Radiação Refletida Total do dia (KW/m2)  \
# count                              6914.000000
# mean                                120.182050
# std                                 424.527474
# min                                   0.000000
# 25%                                  42.647500
# 50%                                  65.625000
# 75%                                  98.500000
# max                                6909.000000
#
#        Fluxo positivo de calor no solo Total do dia (KW/m2)  \
# count                                        6914.000000
# mean                                          108.991185
# std                                           716.880089
# min                                          -931.000000
# 25%                                          -201.700000
# 50%                                            26.230000
# 75%                                            81.275000
# max                                          6924.000000
#
#        Temperatura do Ar Mínima do dia (°C)  \
# count                           6913.000000
# mean                              51.907359
# std                              466.418455
# min                                0.000000
# 25%                               14.020000
# 50%                               16.910000
# 75%                               19.040000
# max                             6991.000000
#
#        Horário de ocorrência da Temp. Ar Minima  \
# count                               6913.000000
# mean                                 791.598438
# std                                  656.412518
# min                                    0.000000
# 25%                                  501.000000
# 50%                                  558.000000
# 75%                                  652.000000
# max                                 2400.000000
#
#        Temperatura do Solo 1 Mínima do dia (°C)  \
# count                               6913.000000
# mean                                 783.914700
# std                                 2249.099354
# min                                -6999.000000
# 25%                                   15.480000
# 50%                                   19.770000
# 75%                                   22.910000
# max                                 6999.000000
#
#        Horário de ocorrência da Temp. Solo 1 minima  Chuva total do dia (mm)
# count                                    6912.00000              6763.000000
# mean                                      783.52474               252.199053
# std                                       611.03749               992.209132
# min                                         0.00000                 0.000000
# 25%                                       559.00000                 0.000000
# 50%                                       649.00000                 0.000000
# 75%                                       732.25000                 2.540000
# max                                      2400.00000              6858.000000

# %% [markdown]
# ### Analyzing 333 data frame

# %%
data_frame_333.head(2)
# Out:
#    Cod   Ano  Dia Juliano Hora - minuto  \
# 0  333  1997          1.0           700
# 1  333  1997          1.0           900
#
#    Veloc. Instantânea do Vento a 5 metros (m/s)  \
# 0                                        3344.0
# 1                                        2618.0
#
#    Veloc. Instantânea do Vento a 2 metros (m/s)  \
# 0                                        1973.0
# 1                                        1544.0
#
#    Direção do Vento no instantânea  (°)  Umidade relativa Instantânea  (%)  \
# 0                                  89.1                               89.7
# 1                                 185.6                               80.2
#
#    Temperatura do Ar Instantânea (°C) Pressão
# 0                               20.47     942
# 1                               23.38     944

# %%
data_frame_333.columns
# Out:
# Index(['Cod', 'Ano', 'Dia Juliano', 'Hora - minuto',
#        'Veloc. Instantânea do Vento a 5 metros (m/s)',
#        'Veloc. Instantânea do Vento a 2 metros (m/s)',
#        'Direção do Vento no instantânea  (°)',
#        'Umidade relativa Instantânea  (%)',
#        'Temperatura do Ar Instantânea (°C)', 'Pressão'],
#       dtype='object')

# %%
data_frame_333.Cod.unique()
# Out:
# array([333], dtype=object)

# %%
print(data_frame_333[data_frame_333.Cod != 333][columns.YEAR].unique())
# Out:
# []

# %%
data_frame_333.isnull().sum()
# Out:
# Cod                                             0
# Ano                                             0
# Dia Juliano                                     0
# Hora - minuto                                   0
# Veloc. Instantânea do Vento a 5 metros (m/s)    0
# Veloc. Instantânea do Vento a 2 metros (m/s)    0
# Direção do Vento no instantânea  (°)            0
# Umidade relativa Instantânea  (%)               0
# Temperatura do Ar Instantânea (°C)              0
# Pressão                                         0
# dtype: int64

# %%
data_frame_333.describe()
# Out:
#         Dia Juliano  Veloc. Instantânea do Vento a 5 metros (m/s)  \
# count  26001.000000                                  26001.000000
# mean     180.482874                                   1434.967665
# std      105.504686                                   1268.984601
# min      -53.360000                                      0.000000
# 25%       89.000000                                      1.010000
# 50%      179.000000                                   1481.000000
# 75%      272.000000                                   2187.000000
# max      366.000000                                   6895.000000
#
#        Veloc. Instantânea do Vento a 2 metros (m/s)  \
# count                                  26001.000000
# mean                                    1041.404223
# std                                     1124.401471
# min                                        0.000000
# 25%                                        0.763000
# 50%                                     1167.000000
# 75%                                     1743.000000
# max                                     6679.000000
#
#        Direção do Vento no instantânea  (°)  \
# count                          26001.000000
# mean                             300.222295
# std                              727.433045
# min                                0.000000
# 25%                               96.500000
# 50%                              158.400000
# 75%                              275.000000
# max                             6952.000000
#
#        Umidade relativa Instantânea  (%)  Temperatura do Ar Instantânea (°C)
# count                       26001.000000                        26001.000000
# mean                           69.928546                           27.642355
# std                            19.715930                          173.852086
# min                             7.770000                         -165.200000
# 25%                            54.920000                           19.140000
# 50%                            72.300000                           22.500000
# 75%                            85.600000                           26.680000
# max                           100.000000                         6999.000000

# %% [markdown]
# ### Analyzing 265 data frame

# %%
data_frame_265.head(2)
# Out:
#    Cod   Ano  Dia Juliano Hora - minuto  Chuva das 7 h as 7 h  \
# 0  265  1997          1.0           700                   0.0
# 1  265  1997          2.0           700                   0.0
#
#    Temperatura do Ar máxima do dia °C  \
# 0                               31.11
# 1                               30.16
#
#   Horário de ocorrência da Temp. Ar máxima  \
# 0                                     1356
# 1                                     1255
#
#    Temperatura do Ar Minima do dia (°C)  \
# 0                                 18.50
# 1                                 19.21
#
#    Horário de ocorrência da Temp. Ar minima  Umidade máxima  Hora  \
# 0                                     551.0             NaN   NaN
# 1                                     510.0             NaN   NaN
#
#    Umidade mínima  Hora.1
# 0             NaN     NaN
# 1             NaN     NaN

# %%
data_frame_265.columns
# Out:
# Index(['Cod', 'Ano', 'Dia Juliano', 'Hora - minuto', 'Chuva das 7 h as 7 h',
#        'Temperatura do Ar máxima do dia °C',
#        'Horário de ocorrência da Temp. Ar máxima',
#        'Temperatura do Ar Minima do dia (°C)',
#        'Horário de ocorrência da Temp. Ar minima', 'Umidade máxima', 'Hora',
#        'Umidade mínima', 'Hora.1'],
#       dtype='object')

# %%
data_frame_265.Cod.unique()
# Out:
# array([265], dtype=object)

# %%
print(data_frame_265[data_frame_265.Cod != 265][columns.YEAR].unique())
# Out:
# []

# %%
data_frame_265.isnull().sum()
# Out:
# Cod                                          0
# Ano                                          0
# Dia Juliano                                  0
# Hora - minuto                                0
# Chuva das 7 h as 7 h                         0
# Temperatura do Ar máxima do dia °C           0
# Horário de ocorrência da Temp. Ar máxima     0
# Temperatura do Ar Minima do dia (°C)         5
# Horário de ocorrência da Temp. Ar minima     5
# Umidade máxima                              57
# Hora                                        57
# Umidade mínima                              57
# Hora.1                                      57
# dtype: int64

# %%
data_frame_265.describe()
# Out:
#        Dia Juliano  Chuva das 7 h as 7 h  Temperatura do Ar máxima do dia °C  \
# count  6864.000000           6864.000000                         6864.000000
# mean    183.431911            259.223644                           30.550498
# std     105.584961           1013.569334                          119.044092
# min     -53.360000              0.000000                           11.660000
# 25%      92.000000              0.000000                           26.140000
# 50%     184.000000              0.000000                           28.860000
# 75%     275.000000              2.540000                           31.380000
# max     366.000000           6999.000000                         6999.000000
#
#        Temperatura do Ar Minima do dia (°C)  \
# count                           6859.000000
# mean                              64.955059
# std                              555.781940
# min                            -6999.000000
# 25%                               13.780000
# 50%                               16.910000
# 75%                               19.170000
# max                             6991.000000
#
#        Horário de ocorrência da Temp. Ar minima  Umidade máxima         Hora  \
# count                               6859.000000     6807.000000  6807.000000
# mean                                 600.501385       92.501716   681.093874
# std                                  310.560816        7.417340   402.932153
# min                                -6999.000000       51.080000     1.000000
# 25%                                  509.000000       88.400000   519.000000
# 50%                                  606.000000       94.000000   638.000000
# 75%                                  701.000000       99.100000   702.000000
# max                                 2400.000000      100.000000  2359.000000
#
#        Umidade mínima       Hora.1
# count     6807.000000  6807.000000
# mean        47.692695  1427.192596
# std        105.982793   245.718799
# min      -6999.000000 -6999.000000
# 25%         37.235000  1346.000000
# 50%         46.550000  1449.000000
# 75%         57.210000  1544.000000
# max       5044.000000  2353.000000
